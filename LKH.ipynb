# %%
import os
import subprocess
import plotly.graph_objects as go

from collections import defaultdict

# %%
class Instance:
    def __init__(self, name: str, tool_count: int, slot_count: int, matrix: list[list[int]], soa_cost: int = None, solution: list[int] = None):
        self.name = name
        self.tool_count = tool_count
        self.slot_count = slot_count
        self.matrix = matrix
        self.soa_cost= soa_cost
        self.solution = solution
        
    def mount_lkh_par_prompt(self, dir: str = "") -> str:
        return (
            f"PROBLEM_FILE = {dir}{self.name}.tsp\n"
            f"OUTPUT_TOUR_FILE = {dir}{self.name}.tour\n"
            "RUNS = 1\n"
        )

    def mount_lkh_tsp_prompt(self) -> str:
        header = (
            f"NAME: {self.name}\n"
            "TYPE: TSP\n"
            f"DIMENSION: {self.tool_count}\n"
            "EDGE_WEIGHT_TYPE: EXPLICIT\n"
            "EDGE_WEIGHT_FORMAT: FULL_MATRIX\n"
            "EDGE_WEIGHT_SECTION\n"
        )
        matrix = "\n".join(" ".join(str(-x) for x in row) for row in self.matrix)
        return f"{header}{matrix}\nEOF"
        
    def calculate_cost(self) -> int:
        tool_index = {tool: idx for idx, tool in enumerate(self.solution)}
        total_cost = 0

        for i in range(self.tool_count):
            for j in range(i + 1, self.tool_count):
                freq = self.matrix[i][j]
                if freq == 0:
                    continue

                dist = abs(tool_index[i] - tool_index[j])
                circular_dist = min(dist, (self.tool_count - dist) + (self.slot_count - self.tool_count))
                total_cost += freq * circular_dist

        return total_cost

# %%
def plot_cost_comparison(plot_data: dict, template="plotly_white", prefix: str = None):
    import re
    def extract_number(name):
        numbers = re.findall(r'\d+', name)
        return int(numbers[0]) if numbers else float('inf')

    # Filter and sort only instances matching the prefix (if provided)
    filtered_instances = [
        inst for inst in plot_data.keys()
        if prefix is None or inst.startswith(prefix)
    ]
    sorted_instances = sorted(filtered_instances, key=extract_number)

    # Extract costs using the sorted + filtered instances
    lkh_costs = [plot_data[inst]["LKH"] for inst in sorted_instances]
    soa_costs = [plot_data[inst]["SOA"] for inst in sorted_instances]

    # Plot
    fig = go.Figure(data=[
        go.Bar(
            y=sorted_instances,
            x=soa_costs,
            name='SOA',
            orientation='h',
            marker_color='#FF0000',
            text=[f"{x:.2f}" for x in soa_costs],
            textposition='outside',
            hoverinfo='x+y+name'
        ),
        go.Bar(
            y=sorted_instances,
            x=lkh_costs,
            name='LKH',
            orientation='h',
            marker_color='#0000FF',
            text=[f"{x:.2f}" for x in lkh_costs],
            textposition='outside',
            hoverinfo='x+y+name'
        )
    ])

    fig.update_layout(
        title='Cost Comparison (LKH vs SOA)',
        xaxis_title='Cost',
        yaxis_title='Instance',
        barmode='group',
        template=template,
        width=1000,
        height=600 + len(sorted_instances) * 10,
        font=dict(size=12),
        margin=dict(l=100, r=50, t=50, b=50)
    )

    fig.show()

# %%
solutions = []
instances = {}
main_dir = "/home/pedro/Pessoal/MSc/tip/instances"
for root, dirs, files in os.walk(main_dir):
    if root != main_dir:
        txt_files = [f for f in files if f.endswith(".txt")]
        for file in txt_files:
            file_path = os.path.join(root, file)
            with open(file_path, 'r', encoding='utf-8') as f:
                lines = f.readlines()
                tool_count, slot_count = map(int, lines[0].strip().split())
                instance = Instance(
                    name=file[:-4],
                    tool_count=tool_count,
                    slot_count=slot_count,
                    soa_cost=int(lines[2].replace('\n', '').strip()),
                    matrix=[[int(x) for x in line.strip().split()] for line in lines[3:] if line != '\n']
                )
                instances[instance.name] = instance

# %%
lkh_path = "/home/pedro/Pessoal/MSc/tip/src/LKH/LKH"
for name, instance in instances.items():
    dir = "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/"
    par_content = instance.mount_lkh_par_prompt(dir)
    tsp_content = instance.mount_lkh_tsp_prompt()

    par_path = os.path.join(dir, f"{name}.par")
    with open(par_path, "w", encoding="utf-8") as f:
        f.write(par_content)

    tsp_path = os.path.join(dir, f"{name}.tsp")
    with open(tsp_path, "w", encoding="utf-8") as f:
        f.write(tsp_content)
        
    print(f"Running LKH for instance {name}...")
    subprocess.run([lkh_path, par_path], check=True)
# Out:
# Running LKH for instance o-10_t_2...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_2.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_2.tsp" ... done
# ASCENT_CANDIDATES = 9
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.1
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 10
# MAX_TRIALS = 10
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_2.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_2.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -168.1, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# * 1: Cost = -168, Time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_2.tour" ... done
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_2.tour" ... done
# Run 1: Cost = -168, Time = 0.00 sec.
#
# Successes/Runs = 0/1
# Cost.min = -168, Cost.avg = -168.00, Cost.max = -168
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 10, Trials.avg = 10.0, Trials.max = 10
# Time.min = 0.00 sec., Time.avg = 0.00 sec., Time.max = 0.00 sec.
# Time.total = 0.00 sec.
# Running LKH for instance o-5_t...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-5_t.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-5_t.tsp" ... done
# ASCENT_CANDIDATES = 4
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.2
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 4
# MAX_SWAPS = 5
# MAX_TRIALS = 5
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-5_t.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 4
# POPMUSIC_SAMPLE_SIZE = 5
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-5_t.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -60.0, Ascent time = 0.00 sec.
# Cand.min = 4, Cand.avg = 4.0, Cand.max = 4
# Preprocessing time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-5_t.tour" ... done
# Successes/Runs = 1/0
# Cost.min = -60, Cost.avg = -60.00, Cost.max = -60
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 0, Trials.avg = 0.0, Trials.max = 0
# Time.min = 0.00 sec., Time.avg = 0.00 sec., Time.max = 0.00 sec.
# Time.total = 0.00 sec.
# Running LKH for instance o-10_t_6...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_6.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_6.tsp" ... done
# ASCENT_CANDIDATES = 9
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.1
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 10
# MAX_TRIALS = 10
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_6.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_6.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -168.1, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# * 1: Cost = -168, Time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_6.tour" ... done
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_6.tour" ... done
# Run 1: Cost = -168, Time = 0.00 sec.
#
# Successes/Runs = 0/1
# Cost.min = -168, Cost.avg = -168.00, Cost.max = -168
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 10, Trials.avg = 10.0, Trials.max = 10
# Time.min = 0.00 sec., Time.avg = 0.00 sec., Time.max = 0.00 sec.
# Time.total = 0.00 sec.
# Running LKH for instance o-15_t...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-15_t.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-15_t.tsp" ... done
# ASCENT_CANDIDATES = 14
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.0666667
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 15
# MAX_TRIALS = 15
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-15_t.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-15_t.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -272.0, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# * 1: Cost = -272, Time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-15_t.tour" ... done
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-15_t.tour" ... done
# Run 1: Cost = -272, Time = 0.00 sec.
#
# Successes/Runs = 0/1
# Cost.min = -272, Cost.avg = -272.00, Cost.max = -272
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 15, Trials.avg = 15.0, Trials.max = 15
# Time.min = 0.00 sec., Time.avg = 0.00 sec., Time.max = 0.00 sec.
# Time.total = 0.00 sec.
# Running LKH for instance o-10_t_4...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_4.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_4.tsp" ... done
# ASCENT_CANDIDATES = 9
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.1
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 10
# MAX_TRIALS = 10
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_4.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_4.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -168.1, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# * 1: Cost = -168, Time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_4.tour" ... done
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_4.tour" ... done
# Run 1: Cost = -168, Time = 0.00 sec.
#
# Successes/Runs = 0/1
# Cost.min = -168, Cost.avg = -168.00, Cost.max = -168
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 10, Trials.avg = 10.0, Trials.max = 10
# Time.min = 0.00 sec., Time.avg = 0.00 sec., Time.max = 0.00 sec.
# Time.total = 0.00 sec.
# Running LKH for instance o-9_t...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-9_t.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-9_t.tsp" ... done
# ASCENT_CANDIDATES = 8
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.111111
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 9
# MAX_TRIALS = 9
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-9_t.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 9
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-9_t.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -146.0, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-9_t.tour" ... done
# Successes/Runs = 1/0
# Cost.min = -146, Cost.avg = -146.00, Cost.max = -146
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 0, Trials.avg = 0.0, Trials.max = 0
# Time.min = 0.00 sec., Time.avg = 0.00 sec., Time.max = 0.00 sec.
# Time.total = 0.00 sec.
# Running LKH for instance o-15_t_2...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-15_t_2.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-15_t_2.tsp" ... done
# ASCENT_CANDIDATES = 14
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.0666667
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 15
# MAX_TRIALS = 15
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-15_t_2.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-15_t_2.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -272.0, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# * 1: Cost = -272, Time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-15_t_2.tour" ... done
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-15_t_2.tour" ... done
# Run 1: Cost = -272, Time = 0.00 sec.
#
# Successes/Runs = 0/1
# Cost.min = -272, Cost.avg = -272.00, Cost.max = -272
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 15, Trials.avg = 15.0, Trials.max = 15
# Time.min = 0.00 sec., Time.avg = 0.00 sec., Time.max = 0.00 sec.
# Time.total = 0.00 sec.
# Running LKH for instance o-7_t...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-7_t.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-7_t.tsp" ... done
# ASCENT_CANDIDATES = 6
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.142857
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 7
# MAX_TRIALS = 7
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-7_t.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 7
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-7_t.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -98.0, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-7_t.tour" ... done
# Successes/Runs = 1/0
# Cost.min = -98, Cost.avg = -98.00, Cost.max = -98
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 0, Trials.avg = 0.0, Trials.max = 0
# Time.min = 0.00 sec., Time.avg = 0.00 sec., Time.max = 0.00 sec.
# Time.total = 0.00 sec.
# Running LKH for instance o-10_t...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t.tsp" ... done
# ASCENT_CANDIDATES = 9
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.1
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 10
# MAX_TRIALS = 10
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -168.1, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# * 1: Cost = -168, Time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t.tour" ... done
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t.tour" ... done
# Run 1: Cost = -168, Time = 0.00 sec.
#
# Successes/Runs = 0/1
# Cost.min = -168, Cost.avg = -168.00, Cost.max = -168
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 10, Trials.avg = 10.0, Trials.max = 10
# Time.min = 0.00 sec., Time.avg = 0.00 sec., Time.max = 0.00 sec.
# Time.total = 0.00 sec.
# Running LKH for instance o-10_t_3...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_3.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_3.tsp" ... done
# ASCENT_CANDIDATES = 9
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.1
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 10
# MAX_TRIALS = 10
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_3.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_3.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -168.1, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# * 1: Cost = -168, Time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_3.tour" ... done
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_3.tour" ... done
# Run 1: Cost = -168, Time = 0.00 sec.
#
# Successes/Runs = 0/1
# Cost.min = -168, Cost.avg = -168.00, Cost.max = -168
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 10, Trials.avg = 10.0, Trials.max = 10
# Time.min = 0.00 sec., Time.avg = 0.00 sec., Time.max = 0.00 sec.
# Time.total = 0.00 sec.
# Running LKH for instance o-20_t...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-20_t.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-20_t.tsp" ... done
# ASCENT_CANDIDATES = 19
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.05
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 20
# MAX_TRIALS = 20
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-20_t.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-20_t.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -376.1, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# * 1: Cost = -376, Time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-20_t.tour" ... done
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-20_t.tour" ... done
# Run 1: Cost = -376, Time = 0.00 sec.
#
# Successes/Runs = 0/1
# Cost.min = -376, Cost.avg = -376.00, Cost.max = -376
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 20, Trials.avg = 20.0, Trials.max = 20
# Time.min = 0.00 sec., Time.avg = 0.00 sec., Time.max = 0.00 sec.
# Time.total = 0.00 sec.
# Running LKH for instance o-5_t_2...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-5_t_2.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-5_t_2.tsp" ... done
# ASCENT_CANDIDATES = 4
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.2
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 4
# MAX_SWAPS = 5
# MAX_TRIALS = 5
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-5_t_2.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 4
# POPMUSIC_SAMPLE_SIZE = 5
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-5_t_2.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -60.0, Ascent time = 0.00 sec.
# Cand.min = 4, Cand.avg = 4.0, Cand.max = 4
# Preprocessing time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-5_t_2.tour" ... done
# Successes/Runs = 1/0
# Cost.min = -60, Cost.avg = -60.00, Cost.max = -60
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 0, Trials.avg = 0.0, Trials.max = 0
# Time.min = 0.00 sec., Time.avg = 0.00 sec., Time.max = 0.00 sec.
# Time.total = 0.00 sec.
# Running LKH for instance o-10_t_5...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_5.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_5.tsp" ... done
# ASCENT_CANDIDATES = 9
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.1
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 10
# MAX_TRIALS = 10
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_5.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_5.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -168.1, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# * 1: Cost = -168, Time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_5.tour" ... done
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-10_t_5.tour" ... done
# Run 1: Cost = -168, Time = 0.00 sec.
#
# Successes/Runs = 0/1
# Cost.min = -168, Cost.avg = -168.00, Cost.max = -168
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 10, Trials.avg = 10.0, Trials.max = 10
# Time.min = 0.00 sec., Time.avg = 0.00 sec., Time.max = 0.00 sec.
# Time.total = 0.00 sec.
# Running LKH for instance o-8_t...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-8_t.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-8_t.tsp" ... done
# ASCENT_CANDIDATES = 7
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.125
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 8
# MAX_TRIALS = 8
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-8_t.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 8
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-8_t.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -126.0, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-8_t.tour" ... done
# Successes/Runs = 1/0
# Cost.min = -126, Cost.avg = -126.00, Cost.max = -126
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 0, Trials.avg = 0.0, Trials.max = 0
# Time.min = 0.00 sec., Time.avg = 0.00 sec., Time.max = 0.00 sec.
# Time.total = 0.00 sec.
# Running LKH for instance o-6_t...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-6_t.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-6_t.tsp" ... done
# ASCENT_CANDIDATES = 5
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.166667
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 6
# MAX_TRIALS = 6
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-6_t.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 6
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-6_t.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -78.0, Ascent time = 0.00 sec.
# Cand.min = 4, Cand.avg = 4.7, Cand.max = 5
# Preprocessing time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/o-6_t.tour" ... done
# Successes/Runs = 1/0
# Cost.min = -78, Cost.avg = -78.00, Cost.max = -78
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 0, Trials.avg = 0.0, Trials.max = 0
# Time.min = 0.00 sec., Time.avg = 0.00 sec., Time.max = 0.00 sec.
# Time.total = 0.00 sec.
# Running LKH for instance anjos-60-05...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-60-05.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-60-05.tsp" ... done
# ASCENT_CANDIDATES = 50
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.0166667
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 60
# MAX_TRIALS = 60
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-60-05.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-60-05.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -111.4, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# * 1: Cost = -111, Time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-60-05.tour" ... done
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-60-05.tour" ... done
# Run 1: Cost = -111, Time = 0.03 sec.
#
# Successes/Runs = 0/1
# Cost.min = -111, Cost.avg = -111.00, Cost.max = -111
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 60, Trials.avg = 60.0, Trials.max = 60
# Time.min = 0.03 sec., Time.avg = 0.03 sec., Time.max = 0.03 sec.
# Time.total = 0.03 sec.
# Running LKH for instance anjos-80-01...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-80-01.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-80-01.tsp" ... done
# ASCENT_CANDIDATES = 50
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.0125
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 80
# MAX_TRIALS = 80
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-80-01.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-80-01.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -190.4, Ascent time = 0.01 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.01 sec.
# * 1: Cost = -190, Time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-80-01.tour" ... done
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-80-01.tour" ... done
# Run 1: Cost = -190, Time = 0.02 sec.
#
# Successes/Runs = 0/1
# Cost.min = -190, Cost.avg = -190.00, Cost.max = -190
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 80, Trials.avg = 80.0, Trials.max = 80
# Time.min = 0.02 sec., Time.avg = 0.02 sec., Time.max = 0.02 sec.
# Time.total = 0.03 sec.
# Running LKH for instance anjos-75-03...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-75-03.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-75-03.tsp" ... done
# ASCENT_CANDIDATES = 50
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.0133333
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 75
# MAX_TRIALS = 75
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-75-03.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-75-03.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -164.8, Ascent time = 0.01 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.01 sec.
# * 1: Cost = -164, Time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-75-03.tour" ... done
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-75-03.tour" ... done
# Run 1: Cost = -164, Time = 0.03 sec.
#
# Successes/Runs = 0/1
# Cost.min = -164, Cost.avg = -164.00, Cost.max = -164
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 75, Trials.avg = 75.0, Trials.max = 75
# Time.min = 0.03 sec., Time.avg = 0.03 sec., Time.max = 0.03 sec.
# Time.total = 0.03 sec.
# Running LKH for instance anjos-70-03...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-70-03.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-70-03.tsp" ... done
# ASCENT_CANDIDATES = 50
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.0142857
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 70
# MAX_TRIALS = 70
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-70-03.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-70-03.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -182.6, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# * 1: Cost = -182, Time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-70-03.tour" ... done
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-70-03.tour" ... done
# Run 1: Cost = -182, Time = 0.02 sec.
#
# Successes/Runs = 0/1
# Cost.min = -182, Cost.avg = -182.00, Cost.max = -182
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 70, Trials.avg = 70.0, Trials.max = 70
# Time.min = 0.02 sec., Time.avg = 0.02 sec., Time.max = 0.02 sec.
# Time.total = 0.02 sec.
# Running LKH for instance anjos-75-04_2...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-75-04_2.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-75-04_2.tsp" ... done
# ASCENT_CANDIDATES = 50
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.0133333
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 75
# MAX_TRIALS = 75
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-75-04_2.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-75-04_2.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -305.6, Ascent time = 0.01 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.01 sec.
# * 1: Cost = -305, Time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-75-04_2.tour" ... done
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-75-04_2.tour" ... done
# Run 1: Cost = -305, Time = 0.01 sec.
#
# Successes/Runs = 0/1
# Cost.min = -305, Cost.avg = -305.00, Cost.max = -305
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 75, Trials.avg = 75.0, Trials.max = 75
# Time.min = 0.01 sec., Time.avg = 0.01 sec., Time.max = 0.01 sec.
# Time.total = 0.02 sec.
# Running LKH for instance anjos-60-04...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-60-04.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-60-04.tsp" ... done
# ASCENT_CANDIDATES = 50
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.0166667
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 60
# MAX_TRIALS = 60
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-60-04.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-60-04.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -99.3, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# * 1: Cost = -99, Time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-60-04.tour" ... done
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-60-04.tour" ... done
# Run 1: Cost = -99, Time = 0.01 sec.
#
# Successes/Runs = 0/1
# Cost.min = -99, Cost.avg = -99.00, Cost.max = -99
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 60, Trials.avg = 60.0, Trials.max = 60
# Time.min = 0.01 sec., Time.avg = 0.01 sec., Time.max = 0.01 sec.
# Time.total = 0.02 sec.
# Running LKH for instance anjos-60-03...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-60-03.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-60-03.tsp" ... done
# ASCENT_CANDIDATES = 50
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.0166667
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 60
# MAX_TRIALS = 60
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-60-03.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-60-03.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -135.4, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# * 1: Cost = -135, Time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-60-03.tour" ... done
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-60-03.tour" ... done
# Run 1: Cost = -135, Time = 0.06 sec.
#
# Successes/Runs = 0/1
# Cost.min = -135, Cost.avg = -135.00, Cost.max = -135
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 60, Trials.avg = 60.0, Trials.max = 60
# Time.min = 0.06 sec., Time.avg = 0.06 sec., Time.max = 0.06 sec.
# Time.total = 0.07 sec.
# Running LKH for instance anjos-80-05...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-80-05.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-80-05.tsp" ... done
# ASCENT_CANDIDATES = 50
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.0125
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 80
# MAX_TRIALS = 80
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-80-05.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-80-05.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -152.7, Ascent time = 0.01 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.01 sec.
# * 1: Cost = -152, Time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-80-05.tour" ... done
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-80-05.tour" ... done
# Run 1: Cost = -152, Time = 0.01 sec.
#
# Successes/Runs = 0/1
# Cost.min = -152, Cost.avg = -152.00, Cost.max = -152
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 80, Trials.avg = 80.0, Trials.max = 80
# Time.min = 0.01 sec., Time.avg = 0.01 sec., Time.max = 0.01 sec.
# Time.total = 0.02 sec.
# Running LKH for instance anjos-75-05...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-75-05.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-75-05.tsp" ... done
# ASCENT_CANDIDATES = 50
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.0133333
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 75
# MAX_TRIALS = 75
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-75-05.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-75-05.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -180.5, Ascent time = 0.01 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.01 sec.
# * 1: Cost = -180, Time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-75-05.tour" ... done
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-75-05.tour" ... done
# Run 1: Cost = -180, Time = 0.02 sec.
#
# Successes/Runs = 0/1
# Cost.min = -180, Cost.avg = -180.00, Cost.max = -180
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 75, Trials.avg = 75.0, Trials.max = 75
# Time.min = 0.02 sec., Time.avg = 0.02 sec., Time.max = 0.02 sec.
# Time.total = 0.02 sec.
# Running LKH for instance anjos-80-04...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-80-04.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-80-04.tsp" ... done
# ASCENT_CANDIDATES = 50
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.0125
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 80
# MAX_TRIALS = 80
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-80-04.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/anjos-80-04.tsp
# ...
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -498.0, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# * 1: Cost = -498, Time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-21_t.tour" ... done
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-21_t.tour" ... done
# Run 1: Cost = -498, Time = 0.00 sec.
#
# Successes/Runs = 0/1
# Cost.min = -498, Cost.avg = -498.00, Cost.max = -498
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 21, Trials.avg = 21.0, Trials.max = 21
# Time.min = 0.00 sec., Time.avg = 0.00 sec., Time.max = 0.00 sec.
# Time.total = 0.00 sec.
# Running LKH for instance s-18_t...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-18_t.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-18_t.tsp" ... done
# ASCENT_CANDIDATES = 17
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.0555556
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 18
# MAX_TRIALS = 18
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-18_t.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-18_t.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -433.0, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# * 1: Cost = -433, Time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-18_t.tour" ... done
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-18_t.tour" ... done
# Run 1: Cost = -433, Time = 0.00 sec.
#
# Successes/Runs = 0/1
# Cost.min = -433, Cost.avg = -433.00, Cost.max = -433
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 18, Trials.avg = 18.0, Trials.max = 18
# Time.min = 0.00 sec., Time.avg = 0.00 sec., Time.max = 0.00 sec.
# Time.total = 0.00 sec.
# Running LKH for instance s-20_t...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-20_t.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-20_t.tsp" ... done
# ASCENT_CANDIDATES = 19
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.05
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 20
# MAX_TRIALS = 20
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-20_t.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-20_t.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -479.1, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# * 1: Cost = -479, Time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-20_t.tour" ... done
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-20_t.tour" ... done
# Run 1: Cost = -479, Time = 0.00 sec.
#
# Successes/Runs = 0/1
# Cost.min = -479, Cost.avg = -479.00, Cost.max = -479
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 20, Trials.avg = 20.0, Trials.max = 20
# Time.min = 0.00 sec., Time.avg = 0.00 sec., Time.max = 0.00 sec.
# Time.total = 0.00 sec.
# Running LKH for instance s-23_t...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-23_t.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-23_t.tsp" ... done
# ASCENT_CANDIDATES = 22
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.0434783
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 23
# MAX_TRIALS = 23
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-23_t.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-23_t.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -550.0, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-23_t.tour" ... done
# Successes/Runs = 1/0
# Cost.min = -550, Cost.avg = -550.00, Cost.max = -550
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 0, Trials.avg = 0.0, Trials.max = 0
# Time.min = 0.00 sec., Time.avg = 0.00 sec., Time.max = 0.00 sec.
# Time.total = 0.00 sec.
# Running LKH for instance s-17_t...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-17_t.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-17_t.tsp" ... done
# ASCENT_CANDIDATES = 16
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.0588235
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 17
# MAX_TRIALS = 17
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-17_t.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-17_t.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -405.0, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-17_t.tour" ... done
# Successes/Runs = 1/0
# Cost.min = -405, Cost.avg = -405.00, Cost.max = -405
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 0, Trials.avg = 0.0, Trials.max = 0
# Time.min = 0.00 sec., Time.avg = 0.00 sec., Time.max = 0.00 sec.
# Time.total = 0.00 sec.
# Running LKH for instance s-13_t_2...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-13_t_2.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-13_t_2.tsp" ... done
# ASCENT_CANDIDATES = 12
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.0769231
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 13
# MAX_TRIALS = 13
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-13_t_2.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-13_t_2.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -307.0, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-13_t_2.tour" ... done
# Successes/Runs = 1/0
# Cost.min = -307, Cost.avg = -307.00, Cost.max = -307
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 0, Trials.avg = 0.0, Trials.max = 0
# Time.min = 0.00 sec., Time.avg = 0.00 sec., Time.max = 0.00 sec.
# Time.total = 0.00 sec.
# Running LKH for instance s-13_t...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-13_t.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-13_t.tsp" ... done
# ASCENT_CANDIDATES = 12
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.0769231
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 13
# MAX_TRIALS = 13
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-13_t.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-13_t.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -307.0, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-13_t.tour" ... done
# Successes/Runs = 1/0
# Cost.min = -307, Cost.avg = -307.00, Cost.max = -307
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 0, Trials.avg = 0.0, Trials.max = 0
# Time.min = 0.00 sec., Time.avg = 0.00 sec., Time.max = 0.00 sec.
# Time.total = 0.00 sec.
# Running LKH for instance s-24_t...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-24_t.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-24_t.tsp" ... done
# ASCENT_CANDIDATES = 23
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.0416667
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 24
# MAX_TRIALS = 24
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-24_t.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-24_t.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -573.4, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# * 1: Cost = -573, Time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-24_t.tour" ... done
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-24_t.tour" ... done
# Run 1: Cost = -573, Time = 0.00 sec.
#
# Successes/Runs = 0/1
# Cost.min = -573, Cost.avg = -573.00, Cost.max = -573
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 24, Trials.avg = 24.0, Trials.max = 24
# Time.min = 0.00 sec., Time.avg = 0.00 sec., Time.max = 0.00 sec.
# Time.total = 0.00 sec.
# Running LKH for instance s-14_t...
# PARAMETER_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-14_t.par
# Reading PROBLEM_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-14_t.tsp" ... done
# ASCENT_CANDIDATES = 13
# BACKBONE_TRIALS = 0
# BACKTRACKING = NO
# # CANDIDATE_FILE =
# CANDIDATE_SET_TYPE = ALPHA
# # EDGE_FILE =
# EXCESS = 0.0714286
# EXTRA_CANDIDATES = 0
# EXTRA_CANDIDATE_SET_TYPE = QUADRANT
# GAIN23 = YES
# GAIN_CRITERION = YES
# INITIAL_PERIOD = 100
# INITIAL_STEP_SIZE = 1
# INITIAL_TOUR_ALGORITHM = WALK
# # INITIAL_TOUR_FILE =
# INITIAL_TOUR_FRACTION = 1.000
# # INPUT_TOUR_FILE =
# KICK_TYPE = 0
# KICKS = 1
# # MAX_BREADTH =
# MAX_CANDIDATES = 5
# MAX_SWAPS = 14
# MAX_TRIALS = 14
# # MERGE_TOUR_FILE =
# MOVE_TYPE = 5
# # NONSEQUENTIAL_MOVE_TYPE = 5
# # OPTIMUM =
# OUTPUT_TOUR_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-14_t.tour
# PATCHING_A = 1
# PATCHING_C = 0
# # PI_FILE =
# POPMUSIC_INITIAL_TOUR = NO
# POPMUSIC_MAX_NEIGHBORS = 5
# POPMUSIC_SAMPLE_SIZE = 10
# POPMUSIC_SOLUTIONS = 50
# POPMUSIC_TRIALS = 1
# # POPULATION_SIZE = 0
# PRECISION = 100
# PROBLEM_FILE = /home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-14_t.tsp
# RECOMBINATION = IPT
# RESTRICTED_SEARCH = YES
# RUNS = 1
# SEED = 1
# STOP_AT_OPTIMUM = YES
# SUBGRADIENT = YES
# # SUBPROBLEM_SIZE =
# # SUBPROBLEM_TOUR_FILE =
# SUBSEQUENT_MOVE_TYPE = 5
# SUBSEQUENT_PATCHING = YES
# # TIME_LIMIT =
# # TOTAL_TIME_LIMIT =
# # TOUR_FILE =
# TRACE_LEVEL = 1
#
# Lower bound = -331.0, Ascent time = 0.00 sec.
# Cand.min = 5, Cand.avg = 5.0, Cand.max = 5
# Preprocessing time = 0.00 sec.
# Writing OUTPUT_TOUR_FILE: "/home/pedro/Pessoal/MSc/tip/src/LKH/IO/s-14_t.tour" ... done
# Successes/Runs = 1/0
# Cost.min = -331, Cost.avg = -331.00, Cost.max = -331
# Gap.min = -0.0000%, Gap.avg = -0.0000%, Gap.max = -0.0000%
# Trials.min = 0, Trials.avg = 0.0, Trials.max = 0
# Time.min = 0.00 sec., Time.avg = 0.00 sec., Time.max = 0.00 sec.
# Time.total = 0.00 sec.

# %%
lkh_path = "/home/pedro/Pessoal/MSc/tip/src/LKH/LKH"
plot_data = {}
for name, instance in instances.items():
    result_path = os.path.join("/home/pedro/Pessoal/MSc/tip/src/LKH/IO/", f"{name}.tour")
    with open(result_path, "r", encoding="utf-8") as f:
        lines = f.readlines()
        solution = [int(line.strip()) - 1 for line in lines[6:-2] if line != '\n']
        instance.solution = solution
        plot_data[name] = {
            "LKH": instance.calculate_cost(),
            "SOA": instance.soa_cost
        }

# %%
plot_cost_comparison(plot_data, prefix="anjos")
